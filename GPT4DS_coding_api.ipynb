# %% [markdown]
# # ChatGPT through Python using api

# %%
# !pip install openai

# %%
import openai

# Don't worry, this isn't my real api :) 
# It's just an example so you can see what an api looks like.
# openai.api_key = 'OkFZyKIk1mZMObg-F4LsfboYl4IkQOM2JrlJGJR23qCIxadfsT3BD'

chat = openai.ChatCompletion.create(
  model='gpt-3.5-turbo',
  messages=[
    {'role':'user',
     'content':'Can you recommend an Italian wine to pair with lasagna?'}
  ])

print(chat.choices[0].message.content)

# %%
# For more info about API and Python integration, see:
# https://platform.openai.com/docs/api-reference/introduction
